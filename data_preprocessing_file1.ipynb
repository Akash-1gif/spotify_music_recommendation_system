# %% [markdown]
# ##### importing essential libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('dark_background')

# %% [markdown]
# ### Step 1: Data Preprocessing:

# %% [markdown]
# #### Step 1.1: fetching the data from the dataset:

# %%
df_meta_data=pd.read_csv('CSV_Files/train.csv')
df_meta_data.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### fetching the shape of this dataset:

# %%
df_meta_data.shape
# Out:
# (114000, 21)

# %% [markdown]
# #### Reducing datapoints for faster processing:
#
# In this ML project, we are considering tracks only from top 10 genres, for faster preprocessing and low processing power

# %% [markdown]
# ##### Finding out all the genres available in this dataset:

# %%
df_meta_data['track_genre'].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'black-metal', 'bluegrass', 'blues', 'brazil',
#        'breakbeat', 'british', 'cantopop', 'chicago-house', 'children',
#        'chill', 'classical', 'club', 'comedy', 'country', 'dance',
#        'dancehall', 'death-metal', 'deep-house', 'detroit-techno',
#        'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm',
#        'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk',
#        'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
#        'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
#        'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'idm', 'indian',
#        'indie-pop', 'indie', 'industrial', 'iranian', 'j-dance', 'j-idol',
#        'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino',
#        'malay', 'mandopop', 'metal', 'metalcore', 'minimal-techno', 'mpb',
#        'new-age', 'opera', 'pagode', 'party', 'piano', 'pop-film', 'pop',
#        'power-pop', 'progressive-house', 'psych-rock', 'punk-rock',
#        'punk', 'r-n-b', 'reggae', 'reggaeton', 'rock-n-roll', 'rock',
#        'rockabilly', 'romance', 'sad', 'salsa', 'samba', 'sertanejo',
#        'show-tunes', 'singer-songwriter', 'ska', 'sleep', 'songwriter',
#        'soul', 'spanish', 'study', 'swedish', 'synth-pop', 'tango',
#        'techno', 'trance', 'trip-hop', 'turkish', 'world-music'],
#       dtype=object)

# %% [markdown]
# The top 10 music genres are: pop,rock,hip-hop,electronic,jazz,classical,r-n-b,country,blues,reggae

# %%
top_10_genres=['pop','rock','hip-hop','electronic','jazz','classical','r-n-b','country','blues','reggae']

# %% [markdown]
# ##### Fetching this subset of tracks that belongs to top 10 genres, this subset will be used in our ML project:

# %%
df_meta_data1=df_meta_data[df_meta_data['track_genre'].isin(top_10_genres)]
df_meta_data1.head()
# Out:
#       Unnamed: 0                track_id                    artists  \
# 8000        8000  5MAK1nd8R6PWnle1Q1WJvh  Everybody Loves an Outlaw
# 8001        8001  2tznHmp70DxMyr2XhWLOW0          Cage The Elephant
# 8002        8002  7vguMCv8uVuZLiQJ156u3Z    Sam Tinnesz;Yacht Money
# 8003        8003  3dPQuX8Gs42Y7b454ybpMR          The White Stripes
# 8004        8004  6zC0mpGYwbNTpk9SKwh08f               Eric Clapton
#
#                                     album_name  \
# 8000                                 I See Red
# 8001                                Melophobia
# 8002        Play with Fire (feat. Yacht Money)
# 8003                                  Elephant
# 8004  Slowhand 35th Anniversary (Super Deluxe)
#
#                               track_name  popularity  duration_ms  explicit  \
# 8000                           I See Red          77       230613     False
# 8001                 Cigarette Daydreams          79       208760     False
# 8002  Play with Fire (feat. Yacht Money)          76       180690     False
# 8003                   Seven Nation Army          84       232106     False
# 8004                   Wonderful Tonight          76       225026     False
#
#       danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 8000         0.509   0.448  ...    -7.552     0       0.0357       0.00713
# 8001         0.636   0.676  ...    -3.442     1       0.0263       0.08070
# 8002         0.573   0.539  ...    -6.091     0       0.0322       0.01620
# 8003         0.743   0.446  ...    -7.807     0       0.0683       0.00390
# 8004         0.572   0.214  ...   -15.625     1       0.0293       0.64900
#
#       instrumentalness  liveness  valence    tempo  time_signature  \
# 8000          0.013700    0.2440    0.221  156.909               3
# 8001          0.000000    0.0831    0.273  113.980               4
# 8002          0.000012    0.1050    0.390   75.012               4
# 8003          0.118000    0.3370    0.278  123.596               4
# 8004          0.129000    0.1250    0.485   95.542               4
#
#       track_genre
# 8000        blues
# 8001        blues
# 8002        blues
# 8003        blues
# 8004        blues
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### Fetching the shape of our dataset that will be used in our ML project:

# %%
df_meta_data1.shape
# Out:
# (10000, 21)

# %% [markdown]
# #### Step 1.2: Data Cleaning

# %% [markdown]
# Removing the instances that has null values in it

# %%
df_meta_data1=df_meta_data1.dropna()

# %%
# evaluating the shape of our dataset after removing the instances with null values:

df_meta_data1.shape
# Out:
# (10000, 21)

# %% [markdown]
# ##### Resetting indices:

# %%
df_meta_data1=df_meta_data1.reset_index(drop=True)
df_meta_data1.head()
# Out:
#    Unnamed: 0                track_id                    artists  \
# 0        8000  5MAK1nd8R6PWnle1Q1WJvh  Everybody Loves an Outlaw
# 1        8001  2tznHmp70DxMyr2XhWLOW0          Cage The Elephant
# 2        8002  7vguMCv8uVuZLiQJ156u3Z    Sam Tinnesz;Yacht Money
# 3        8003  3dPQuX8Gs42Y7b454ybpMR          The White Stripes
# 4        8004  6zC0mpGYwbNTpk9SKwh08f               Eric Clapton
#
#                                  album_name  \
# 0                                 I See Red
# 1                                Melophobia
# 2        Play with Fire (feat. Yacht Money)
# 3                                  Elephant
# 4  Slowhand 35th Anniversary (Super Deluxe)
#
#                            track_name  popularity  duration_ms  explicit  \
# 0                           I See Red          77       230613     False
# 1                 Cigarette Daydreams          79       208760     False
# 2  Play with Fire (feat. Yacht Money)          76       180690     False
# 3                   Seven Nation Army          84       232106     False
# 4                   Wonderful Tonight          76       225026     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.509   0.448  ...    -7.552     0       0.0357       0.00713
# 1         0.636   0.676  ...    -3.442     1       0.0263       0.08070
# 2         0.573   0.539  ...    -6.091     0       0.0322       0.01620
# 3         0.743   0.446  ...    -7.807     0       0.0683       0.00390
# 4         0.572   0.214  ...   -15.625     1       0.0293       0.64900
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.013700    0.2440    0.221  156.909               3        blues
# 1          0.000000    0.0831    0.273  113.980               4        blues
# 2          0.000012    0.1050    0.390   75.012               4        blues
# 3          0.118000    0.3370    0.278  123.596               4        blues
# 4          0.129000    0.1250    0.485   95.542               4        blues
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### Dropping unnecessary columns:

# %%
df=df_meta_data1.drop(['Unnamed: 0','track_id','artists','album_name','duration_ms','explicit','key','mode','time_signature'],axis=1)
df
# Out:
#                               track_name  popularity  danceability  energy  \
# 0                              I See Red          77         0.509   0.448
# 1                    Cigarette Daydreams          79         0.636   0.676
# 2     Play with Fire (feat. Yacht Money)          76         0.573   0.539
# 3                      Seven Nation Army          84         0.743   0.446
# 4                      Wonderful Tonight          76         0.572   0.214
# ...                                  ...         ...           ...     ...
# 9995            Christmas All Over Again           0         0.440   0.838
# 9996            Christmas All Over Again           0         0.440   0.838
# 9997            Christmas All Over Again           0         0.440   0.838
# 9998            Christmas All Over Again           0         0.440   0.838
# 9999            Christmas All Over Again           0         0.440   0.838
#
#       loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0       -7.552       0.0357       0.00713          0.013700    0.2440
# 1       -3.442       0.0263       0.08070          0.000000    0.0831
# 2       -6.091       0.0322       0.01620          0.000012    0.1050
# 3       -7.807       0.0683       0.00390          0.118000    0.3370
# 4      -15.625       0.0293       0.64900          0.129000    0.1250
# ...        ...          ...           ...               ...       ...
# 9995    -6.196       0.0423       0.09560          0.000000    0.4730
# 9996    -6.196       0.0423       0.09560          0.000000    0.4730
# 9997    -6.196       0.0423       0.09560          0.000000    0.4730
# 9998    -6.196       0.0423       0.09560          0.000000    0.4730
# 9999    -6.196       0.0423       0.09560          0.000000    0.4730
#
#       valence    tempo track_genre
# 0       0.221  156.909       blues
# 1       0.273  113.980       blues
# 2       0.390   75.012       blues
# 3       0.278  123.596       blues
# 4       0.485   95.542       blues
# ...       ...      ...         ...
# 9995    0.619  138.908        rock
# 9996    0.619  138.908        rock
# 9997    0.619  138.908        rock
# 9998    0.619  138.908        rock
# 9999    0.619  138.908        rock
#
# [10000 rows x 12 columns]

# %%
df.shape
# Out:
# (10000, 12)

# %% [markdown]
# ##### Allocating a unique id to each song/track:

# %%
df['track_id']=df.index
df.head()
# Out:
#                            track_name  popularity  danceability  energy  \
# 0                           I See Red          77         0.509   0.448
# 1                 Cigarette Daydreams          79         0.636   0.676
# 2  Play with Fire (feat. Yacht Money)          76         0.573   0.539
# 3                   Seven Nation Army          84         0.743   0.446
# 4                   Wonderful Tonight          76         0.572   0.214
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    -7.552       0.0357       0.00713          0.013700    0.2440    0.221
# 1    -3.442       0.0263       0.08070          0.000000    0.0831    0.273
# 2    -6.091       0.0322       0.01620          0.000012    0.1050    0.390
# 3    -7.807       0.0683       0.00390          0.118000    0.3370    0.278
# 4   -15.625       0.0293       0.64900          0.129000    0.1250    0.485
#
#      tempo track_genre  track_id
# 0  156.909       blues         0
# 1  113.980       blues         1
# 2   75.012       blues         2
# 3  123.596       blues         3
# 4   95.542       blues         4

# %%
df.shape
# Out:
# (10000, 13)

# %% [markdown]
# ##### appending track ids to track name for distungishing the songs with similar names:

# %%
def convert_to_str(x):
    return str(x)

# %%
df['track_id1']=df['track_id'].apply(convert_to_str)
df.head()
# Out:
#                            track_name  popularity  danceability  energy  \
# 0                           I See Red          77         0.509   0.448
# 1                 Cigarette Daydreams          79         0.636   0.676
# 2  Play with Fire (feat. Yacht Money)          76         0.573   0.539
# 3                   Seven Nation Army          84         0.743   0.446
# 4                   Wonderful Tonight          76         0.572   0.214
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    -7.552       0.0357       0.00713          0.013700    0.2440    0.221
# 1    -3.442       0.0263       0.08070          0.000000    0.0831    0.273
# 2    -6.091       0.0322       0.01620          0.000012    0.1050    0.390
# 3    -7.807       0.0683       0.00390          0.118000    0.3370    0.278
# 4   -15.625       0.0293       0.64900          0.129000    0.1250    0.485
#
#      tempo track_genre  track_id track_id1
# 0  156.909       blues         0         0
# 1  113.980       blues         1         1
# 2   75.012       blues         2         2
# 3  123.596       blues         3         3
# 4   95.542       blues         4         4

# %%
df['track_name']=df['track_name']+' - '+df['track_id1']
df.head()
# Out:
#                                track_name  popularity  danceability  energy  \
# 0                           I See Red - 0          77         0.509   0.448
# 1                 Cigarette Daydreams - 1          79         0.636   0.676
# 2  Play with Fire (feat. Yacht Money) - 2          76         0.573   0.539
# 3                   Seven Nation Army - 3          84         0.743   0.446
# 4                   Wonderful Tonight - 4          76         0.572   0.214
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    -7.552       0.0357       0.00713          0.013700    0.2440    0.221
# 1    -3.442       0.0263       0.08070          0.000000    0.0831    0.273
# 2    -6.091       0.0322       0.01620          0.000012    0.1050    0.390
# 3    -7.807       0.0683       0.00390          0.118000    0.3370    0.278
# 4   -15.625       0.0293       0.64900          0.129000    0.1250    0.485
#
#      tempo track_genre  track_id track_id1
# 0  156.909       blues         0         0
# 1  113.980       blues         1         1
# 2   75.012       blues         2         2
# 3  123.596       blues         3         3
# 4   95.542       blues         4         4

# %%
df=df.drop(['track_id1'],axis=1)
df.head()
# Out:
#                                track_name  popularity  danceability  energy  \
# 0                           I See Red - 0          77         0.509   0.448
# 1                 Cigarette Daydreams - 1          79         0.636   0.676
# 2  Play with Fire (feat. Yacht Money) - 2          76         0.573   0.539
# 3                   Seven Nation Army - 3          84         0.743   0.446
# 4                   Wonderful Tonight - 4          76         0.572   0.214
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    -7.552       0.0357       0.00713          0.013700    0.2440    0.221
# 1    -3.442       0.0263       0.08070          0.000000    0.0831    0.273
# 2    -6.091       0.0322       0.01620          0.000012    0.1050    0.390
# 3    -7.807       0.0683       0.00390          0.118000    0.3370    0.278
# 4   -15.625       0.0293       0.64900          0.129000    0.1250    0.485
#
#      tempo track_genre  track_id
# 0  156.909       blues         0
# 1  113.980       blues         1
# 2   75.012       blues         2
# 3  123.596       blues         3
# 4   95.542       blues         4

# %% [markdown]
# ##### Evaluating track_genre column:

# %%
df['track_genre'].value_counts()
# Out:
# blues         1000
# classical     1000
# country       1000
# electronic    1000
# hip-hop       1000
# jazz          1000
# pop           1000
# r-n-b         1000
# reggae        1000
# rock          1000
# Name: track_genre, dtype: int64

# %% [markdown]
# #### Step 1.3: Using Label Encoder to convert the track_genre's string values to numerical data:

# %% [markdown]
# ##### importing necessary library and initiating Label Encoder:

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %% [markdown]
# ##### Converting the track_genre's string values into numerical values:

# %%
df['track_genre_num']=le.fit_transform(df['track_genre'])
df.head()
# Out:
#                                track_name  popularity  danceability  energy  \
# 0                           I See Red - 0          77         0.509   0.448
# 1                 Cigarette Daydreams - 1          79         0.636   0.676
# 2  Play with Fire (feat. Yacht Money) - 2          76         0.573   0.539
# 3                   Seven Nation Army - 3          84         0.743   0.446
# 4                   Wonderful Tonight - 4          76         0.572   0.214
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    -7.552       0.0357       0.00713          0.013700    0.2440    0.221
# 1    -3.442       0.0263       0.08070          0.000000    0.0831    0.273
# 2    -6.091       0.0322       0.01620          0.000012    0.1050    0.390
# 3    -7.807       0.0683       0.00390          0.118000    0.3370    0.278
# 4   -15.625       0.0293       0.64900          0.129000    0.1250    0.485
#
#      tempo track_genre  track_id  track_genre_num
# 0  156.909       blues         0                0
# 1  113.980       blues         1                0
# 2   75.012       blues         2                0
# 3  123.596       blues         3                0
# 4   95.542       blues         4                0

# %% [markdown]
# #### Step 1.4: Using MinMax algorithm to normalize all the values:

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0, 100))

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# ##### shortlisting the columns (attributes) that are to be normalized:

# %%
target_columns=['popularity','danceability','energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo','track_genre_num']

# %% [markdown]
# #### Step 1.4.2 Measuring the range of the column (attribute) values that are subjected to normalization: (Data Distribution)
#
# This also shows us that how the range of input variable values are distributed in the dataset, giving us an idea regarding the data distribution (numerically).

# %%
for x in target_columns:
    print(df[x].describe())
    print()
# Out:
# count    10000.0000
# mean        28.0877
# std         29.4978
# min          0.0000
# 25%          0.0000
# 50%         16.0000
# 75%         56.0000
# max        100.0000
# Name: popularity, dtype: float64
#
# count    10000.000000
# mean         0.593863
# std          0.167522
# min          0.000000
# 25%          0.483000
# 50%          0.606000
# 75%          0.718000
# max          0.975000
# Name: danceability, dtype: float64
#
# count    10000.000000
# mean         0.574818
# std          0.244921
# min          0.000071
# 25%          0.416000
# 50%          0.610500
# 75%          0.769000
# max          0.997000
# Name: energy, dtype: float64
#
# count    10000.000000
# mean        -8.710318
# std          5.533403
# min        -41.531000
# 25%        -10.115000
# 50%         -7.145500
# 75%         -5.222000
# max          0.681000
# Name: loudness, dtype: float64
#
# count    10000.000000
# mean         0.075867
# std          0.078859
# min          0.000000
# 25%          0.034700
# 50%          0.046200
# 75%          0.077900
# max          0.924000
# Name: speechiness, dtype: float64
#
# count    10000.000000
# mean         0.382585
# std          0.340831
# min          0.000010
# 25%          0.068400
# 50%          0.271000
# 75%          0.706000
# max          0.996000
# Name: acousticness, dtype: float64
#
# count    10000.000000
# mean         0.104081
# std          0.264749
# min          0.000000
# 25%          0.000000
# 50%          0.000008
# 75%          0.002660
# max          0.982000
# Name: instrumentalness, dtype: float64
#
# count    10000.000000
# mean         0.187063
# std          0.156428
# min          0.015000
# 25%          0.096100
# 50%          0.126000
# 75%          0.234000
# max          0.989000
# Name: liveness, dtype: float64
#
# count    10000.000000
# mean         0.526576
# std          0.249220
# min          0.000000
# 25%          0.331000
# 50%          0.534500
# 75%          0.720000
# max          0.994000
# Name: valence, dtype: float64
#
# count    10000.000000
# mean       119.199019
# std         30.851471
# min          0.000000
# 25%         94.469250
# 50%        117.637000
# 75%        139.940500
# max        243.372000
# Name: tempo, dtype: float64
#
# count    10000.000000
# mean         4.500000
# std          2.872425
# min          0.000000
# 25%          2.000000
# 50%          4.500000
# 75%          7.000000
# max          9.000000
# Name: track_genre_num, dtype: float64

# %% [markdown]
# From the above output, it is evident that different attributes have values in different ranges. Hence feature scaling is necessary for a better Machine Learning model performance. We need to normalize the values in the scale of 0 to 100

# %% [markdown]
# ##### Normalizing the data using MinMax scale:

# %%
df[target_columns]=scaler.fit_transform(df[target_columns])
df.head()
# Out:
#                                track_name  popularity  danceability  \
# 0                           I See Red - 0        77.0     52.205128
# 1                 Cigarette Daydreams - 1        79.0     65.230769
# 2  Play with Fire (feat. Yacht Money) - 2        76.0     58.769231
# 3                   Seven Nation Army - 3        84.0     76.205128
# 4                   Wonderful Tonight - 4        76.0     58.666667
#
#       energy   loudness  speechiness  acousticness  instrumentalness  \
# 0  44.930905  80.496067     3.863636      0.714837          1.395112
# 1  67.801130  90.232635     2.846320      8.101459          0.000000
# 2  54.058933  83.957169     3.484848      1.625489          0.001181
# 3  44.730289  79.891974     7.391775      0.390536         12.016293
# 4  21.458831  61.371174     3.170996     65.160282         13.136456
#
#     liveness    valence      tempo track_genre  track_id  track_genre_num
# 0  23.511294  22.233400  64.472906       blues         0              0.0
# 1   6.991786  27.464789  46.833654       blues         1              0.0
# 2   9.240246  39.235412  30.821952       blues         2              0.0
# 3  33.059548  27.967807  50.784807       blues         3              0.0
# 4  11.293634  48.792757  39.257597       blues         4              0.0

# %% [markdown]
# ##### Verifying whether the data is normalized or not:

# %%
for x in target_columns:
    print(df[x].describe())
    print()
# Out:
# count    10000.0000
# mean        28.0877
# std         29.4978
# min          0.0000
# 25%          0.0000
# 50%         16.0000
# 75%         56.0000
# max        100.0000
# Name: popularity, dtype: float64
#
# count    10000.000000
# mean        60.908993
# std         17.181724
# min          0.000000
# 25%         49.538462
# 50%         62.153846
# 75%         73.641026
# max        100.000000
# Name: danceability, dtype: float64
#
# count    10000.000000
# mean        57.651721
# std         24.567561
# min          0.000000
# 25%         41.721049
# 50%         61.230956
# 75%         77.129775
# max        100.000000
# Name: energy, dtype: float64
#
# count    10000.000000
# mean        77.752019
# std         13.108601
# min          0.000000
# 25%         74.424334
# 50%         81.459064
# 75%         86.015825
# max        100.000000
# Name: loudness, dtype: float64
#
# count    10000.000000
# mean         8.210746
# std          8.534570
# min          0.000000
# 25%          3.755411
# 50%          5.000000
# 75%          8.430736
# max        100.000000
# Name: speechiness, dtype: float64
#
# count    10000.000000
# mean        38.411542
# std         34.220344
# min          0.000000
# 25%          6.866507
# 50%         27.208083
# 75%         70.883233
# max        100.000000
# Name: acousticness, dtype: float64
#
# count    10000.000000
# mean        10.598928
# std         26.960174
# min          0.000000
# 25%          0.000000
# 50%          0.000803
# 75%          0.270876
# max        100.000000
# Name: instrumentalness, dtype: float64
#
# count    10000.000000
# mean        17.665638
# std         16.060335
# min          0.000000
# 25%          8.326489
# 50%         11.396304
# 75%         22.484600
# max        100.000000
# Name: liveness, dtype: float64
#
# count    10000.000000
# mean        52.975423
# std         25.072394
# min          0.000000
# 25%         33.299799
# 50%         53.772636
# 75%         72.434608
# max        100.000000
# Name: valence, dtype: float64
#
# count    10000.000000
# mean        48.978116
# std         12.676672
# min          0.000000
# 25%         38.816811
# 50%         48.336292
# 75%         57.500657
# max        100.000000
# Name: tempo, dtype: float64
#
# count    10000.000000
# mean        50.000000
# std         31.915833
# min          0.000000
# 25%         22.222222
# 50%         50.000000
# 75%         77.777778
# max        100.000000
# Name: track_genre_num, dtype: float64

# %% [markdown]
# The data is normalized

# %% [markdown]
# ### End of Step 1:
#
# In this step, we have shortlisted the input variables (model attributes) that will be used in our machine learning models, performed data preprocessing that includes Categorical Encoding and Feature Scaling

# %% [markdown]
# #### saving the following dataframe in the form of pickles and .csv file

# %%
import joblib
df.to_pickle('Artifacts/unlabelled_dataframe.pkl')
df.to_csv('CSV_Files/unlabelled_data.csv',index=False)
